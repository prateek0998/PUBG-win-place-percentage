# %%
import pandas as pd

# %%
#importing the training data
pubg=pd.read_csv('train_V2.csv')
pubg.head(10)
# Out:
#                Id         groupId         matchId  assists  boosts  \
# 0  7f96b2f878858a  4d4b580de459be  a10357fd1a4a91        0       0
# 1  eef90569b9d03c  684d5656442f9e  aeb375fc57110c        0       0
# 2  1eaf90ac73de72  6a4a42c3245a74  110163d8bb94ae        1       0
# 3  4616d365dd2853  a930a9c79cd721  f1f1f4ef412d7e        0       0
# 4  315c96c26c9aac  de04010b3458dd  6dc8ff871e21e6        0       0
# 5  ff79c12f326506  289a6836a88d27  bac52627a12114        0       0
# 6  95959be0e21ca3  2c485a1ad3d0f1  a8274e903927a2        0       0
# 7  311b84c6ff4390  eaba5fcb7fc1ae  292611730ca862        0       0
# 8  1a68204ccf9891  47cfbb04e1b1a2  df014fbee741c6        0       0
# 9  e5bb5a43587253  759bb6f7514fd2  3d3031c795305b        0       0
#
#    damageDealt  DBNOs  headshotKills  heals  killPlace      ...       revives  \
# 0        0.000      0              0      0         60      ...             0
# ...

# %%
pubg.dropna()
# Out:
#                      Id         groupId         matchId  assists  boosts  \
# 0        7f96b2f878858a  4d4b580de459be  a10357fd1a4a91        0       0
# 1        eef90569b9d03c  684d5656442f9e  aeb375fc57110c        0       0
# 2        1eaf90ac73de72  6a4a42c3245a74  110163d8bb94ae        1       0
# 3        4616d365dd2853  a930a9c79cd721  f1f1f4ef412d7e        0       0
# 4        315c96c26c9aac  de04010b3458dd  6dc8ff871e21e6        0       0
# 5        ff79c12f326506  289a6836a88d27  bac52627a12114        0       0
# 6        95959be0e21ca3  2c485a1ad3d0f1  a8274e903927a2        0       0
# 7        311b84c6ff4390  eaba5fcb7fc1ae  292611730ca862        0       0
# 8        1a68204ccf9891  47cfbb04e1b1a2  df014fbee741c6        0       0
# 9        e5bb5a43587253  759bb6f7514fd2  3d3031c795305b        0       0
# 10       2b574d43972813  c549efede67ad3  2dd6ddb8320fc1        0       0
# 11       8de328a74658a9  f643df9df3877c  80170383d90003        0       0
# ...

# %%
pubg.columns
# Out:
# Index(['Id', 'groupId', 'matchId', 'assists', 'boosts', 'damageDealt', 'DBNOs',
#        'headshotKills', 'heals', 'killPlace', 'killPoints', 'kills',
#        'killStreaks', 'longestKill', 'matchDuration', 'matchType', 'maxPlace',
#        'numGroups', 'rankPoints', 'revives', 'rideDistance', 'roadKills',
#        'swimDistance', 'teamKills', 'vehicleDestroys', 'walkDistance',
#        'weaponsAcquired', 'winPoints', 'winPlacePerc'],
#       dtype='object')

# %%
pubg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4446966 entries, 0 to 4446965
# Data columns (total 29 columns):
# Id                 object
# groupId            object
# matchId            object
# assists            int64
# boosts             int64
# damageDealt        float64
# DBNOs              int64
# headshotKills      int64
# heals              int64
# killPlace          int64
# killPoints         int64
# kills              int64
# killStreaks        int64
# longestKill        float64
# matchDuration      int64
# matchType          object
# maxPlace           int64
# numGroups          int64
# rankPoints         int64
# revives            int64
# rideDistance       float64
# roadKills          int64
# swimDistance       float64
# teamKills          int64
# vehicleDestroys    int64
# walkDistance       float64
# weaponsAcquired    int64
# winPoints          int64
# winPlacePerc       float64
# dtypes: float64(6), int64(19), object(4)
# memory usage: 983.9+ MB

# %%
from sklearn.model_selection import train_test_split

# %%
#Target to br predicted
pubg['winPlacePerc']
# Out:
# 0          0.4444
# 1          0.6400
# 2          0.7755
# 3          0.1667
# 4          0.1875
# 5          0.0370
# 6          0.0000
# 7          0.7368
# 8          0.3704
# 9          0.2143
# 10         0.3929
# 11         0.4043
# 12         0.9286
# 13         0.8750
# 14         0.9000
# 15         0.2766
# 16         0.7308
# 17         0.8211
# 18         0.1923
# 19         0.9310
# 20         0.6383
# 21         0.2143
# 22         0.7500
# 23         0.9592
# 24         0.9231
# 25         0.8696
# 26         0.1154
# 27         0.7234
# 28         0.9630
# 29         0.0000
#             ...
# 4446936    0.7308
# 4446937    0.7111
# 4446938    0.0385
# 4446939    0.3830
# 4446940    0.6250
# 4446941    0.1600
# 4446942    1.0000
# 4446943    0.1111
# 4446944    0.6875
# 4446945    0.1875
# 4446946    0.7292
# 4446947    0.3830
# 4446948    0.7917
# 4446949    0.1458
# 4446950    0.5000
# 4446951    0.1000
# 4446952    0.8462
# 4446953    0.5926
# 4446954    0.5306
# ...

# %%
pubg[:]
# Out:
#                      Id         groupId         matchId  assists  boosts  \
# 0        7f96b2f878858a  4d4b580de459be  a10357fd1a4a91        0       0
# 1        eef90569b9d03c  684d5656442f9e  aeb375fc57110c        0       0
# 2        1eaf90ac73de72  6a4a42c3245a74  110163d8bb94ae        1       0
# 3        4616d365dd2853  a930a9c79cd721  f1f1f4ef412d7e        0       0
# 4        315c96c26c9aac  de04010b3458dd  6dc8ff871e21e6        0       0
# 5        ff79c12f326506  289a6836a88d27  bac52627a12114        0       0
# 6        95959be0e21ca3  2c485a1ad3d0f1  a8274e903927a2        0       0
# 7        311b84c6ff4390  eaba5fcb7fc1ae  292611730ca862        0       0
# 8        1a68204ccf9891  47cfbb04e1b1a2  df014fbee741c6        0       0
# 9        e5bb5a43587253  759bb6f7514fd2  3d3031c795305b        0       0
# 10       2b574d43972813  c549efede67ad3  2dd6ddb8320fc1        0       0
# 11       8de328a74658a9  f643df9df3877c  80170383d90003        0       0
# ...

# %%
x=pubg[['Id', 'groupId', 'matchId', 'assists', 'boosts', 'damageDealt','DBNOs', 'headshotKills', 'heals', 'killPlace', 'killPoints',
       'kills', 'killStreaks', 'longestKill', 'matchDuration','matchType', 'maxPlace', 'numGroups', 'rankPoints', 'revives',
       'rideDistance', 'roadKills', 'swimDistance', 'teamKills','vehicleDestroys', 'walkDistance', 'weaponsAcquired', 'winPoints']]
y=pubg['winPlacePerc']
x
# Out:
#                      Id         groupId         matchId  assists  boosts  \
# 0        7f96b2f878858a  4d4b580de459be  a10357fd1a4a91        0       0
# 1        eef90569b9d03c  684d5656442f9e  aeb375fc57110c        0       0
# 2        1eaf90ac73de72  6a4a42c3245a74  110163d8bb94ae        1       0
# 3        4616d365dd2853  a930a9c79cd721  f1f1f4ef412d7e        0       0
# 4        315c96c26c9aac  de04010b3458dd  6dc8ff871e21e6        0       0
# 5        ff79c12f326506  289a6836a88d27  bac52627a12114        0       0
# 6        95959be0e21ca3  2c485a1ad3d0f1  a8274e903927a2        0       0
# 7        311b84c6ff4390  eaba5fcb7fc1ae  292611730ca862        0       0
# 8        1a68204ccf9891  47cfbb04e1b1a2  df014fbee741c6        0       0
# 9        e5bb5a43587253  759bb6f7514fd2  3d3031c795305b        0       0
# 10       2b574d43972813  c549efede67ad3  2dd6ddb8320fc1        0       0
# 11       8de328a74658a9  f643df9df3877c  80170383d90003        0       0
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=0,test_size = 0.3)#Splitting training set into 70-30 for future models

# %%
len(x_train)
# Out:
# 3112876

# %%
len(x_test)
# Out:
# 1334090

# %%
len(pubg)
# Out:
# 4446966

# %%
x_train.head(10)
# Out:
#                      Id         groupId         matchId  assists  boosts  \
# 802633   c098ac42f9a222  8592abdb5452d5  7e076894f6b6b7        0       0
# 2736325  8aaffd5277c774  39a53d1b729105  d17199d85852f7        0       0
# 2940094  ac5989bd615c87  6ec631de07ea5c  f1dd37adfb4dfd        0       0
# 1297467  67a501f32dbfa1  a3963283c01b96  9d5475325646b5        1       6
# 4061634  d1572fa5775c57  3035a1e0615988  223729a30fd2a0        0       0
# 388851   e8e182102fde8d  1e7d25ab875795  d526999c4be49b        0       0
# 2811829  9b250f693d1756  51420ee8cbf05a  c8b6a89c5d54da        1       0
# 2267717  40dd4be2a81622  f4bf3a1d7e8bf4  4ee30fa2a713ee        1       0
# 1333841  e7ba56d410226e  c2e9eff3a96a95  40855ac0f833ed        1       0
# 1177546  b57bcfa52328dc  ae14064a54ad26  3c71fe9ee54baa        0       0
#
#          damageDealt  DBNOs  headshotKills  heals  killPlace    ...      \
# 802633          0.00      0              0      0         56    ...
# ...

# %%
print("The average person kills {:.4f} players, 99% of people have {} kills or less, while the most kills ever recorded is {}.".format(x_train['kills'].mean(),x_train['kills'].quantile(0.99),x_train['kills'].max()))
# Out:
# The average person kills 0.9250 players, 99% of people have 7.0 kills or less, while the most kills ever recorded is 72.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print("The average person drives for {:.1f}m, 99% of people have drived {}m or less, while the formula 1 champion drived for {}m.".format(x_train['rideDistance'].mean(), x_train['rideDistance'].quantile(0.99), x_train['rideDistance'].max()))
# Out:
# The average person drives for 606.3m, 99% of people have drived 6974.0m or less, while the formula 1 champion drived for 40710.0m.

# %%
print("The average person walks for {:.1f}m, 99% of people have walked {}m or less, while the marathoner champion walked for {}m.".format(x_train['walkDistance'].mean(), x_train['walkDistance'].quantile(0.99), x_train['walkDistance'].max()))
# Out:
# The average person walks for 1154.6m, 99% of people have walked 4399.0m or less, while the marathoner champion walked for 25780.0m.

# %%
print("The average person swims for {:.1f}m, 99% of people have swimemd {}m or less, while the olympic champion swimmed for {}m.".format(x_train['swimDistance'].mean(), x_train['swimDistance'].quantile(0.99), x_train['swimDistance'].max()))
# Out:
# The average person swims for 4.5m, 99% of people have swimemd 122.9m or less, while the olympic champion swimmed for 3823.0m.

# %%
print("The average person uses {:.1f} heal items, 99% of people use {} or less, while the doctor used {}.".format(x_train['heals'].mean(), x_train['heals'].quantile(0.99), x_train['heals'].max()))
print("The average person uses {:.1f} boost items, 99% of people use {} or less, while the doctor used {}.".format(x_train['boosts'].mean(), x_train['boosts'].quantile(0.99), x_train['boosts'].max()))
# Out:
# The average person uses 1.4 heal items, 99% of people use 12.0 or less, while the doctor used 80.
# The average person uses 1.1 boost items, 99% of people use 7.0 or less, while the doctor used 33.

# %%
solos = x_train[x_train['numGroups']>50]
duos = x_train[(x_train['numGroups']>25) & (x_train['numGroups']<=50)]
squads = x_train[x_train['numGroups']<=25]
print("There are {} ({:.2f}%) solo games, {} ({:.2f}%) duo games and {} ({:.2f}%) squad games.".format(len(solos), 100*len(solos)/len(x_train), len(duos), 100*len(duos)/len(x_train), len(squads), 100*len(squads)/len(x_train),))
# Out:
# There are 496471 (15.95%) solo games, 2306243 (74.09%) duo games and 310162 (9.96%) squad games.

# %%
print("The average person knocks out {:.4f} players, 99% of people have {} knocks or less, while the most knocks ever recorded is {}.".format(x_train['DBNOs'].mean(),x_train['DBNOs'].quantile(0.99),x_train['DBNOs'].max()))
# Out:
# The average person knocks out 0.6583 players, 99% of people have 5.0 knocks or less, while the most knocks ever recorded is 40.

# %%
print("{} players ({:.4f}%) walked 0 meters. This means that they die before even taking a step or they are killed on entry with parachute (more possible).".format(len(x_train[x_train['walkDistance'] == 0]), 100*len(x_train[x_train['walkDistance']==0])/len(x_train)))
# Out:
# 69620 players (2.2365%) walked 0 meters. This means that they die before even taking a step or they are killed on entry with parachute (more possible).

# %%
def show_countplot(column):
    plt.figure(figsize=(12,4))
    sns.countplot(data=x_train,x=column).set_title(column)
    plt.show()
'''def show_distplot(column):
    plt.figure(x_train[column].map(int),bins=50)
    plt.show()'''
# Out:
# 'def show_distplot(column):\n    plt.figure(x_train[column].map(int),bins=50)\n    plt.show()'

# %%
#Aim Hacks:They will take control of a player's aim and automatically target it towards opponents
show_countplot('kills')

# %%
pubg.iloc[4303492]
# Out:
# Id                 812e46db8222f1
# groupId            50bfe4b9bdccb3
# matchId            405e08b1bac4ad
# assists                         0
# boosts                          0
# damageDealt                     0
# DBNOs                           0
# headshotKills                   0
# heals                           0
# killPlace                      48
# killPoints                   1000
# kills                           0
# killStreaks                     0
# longestKill                     0
# matchDuration                1419
# matchType                    solo
# maxPlace                       79
# numGroups                      63
# rankPoints                     -1
# revives                         0
# rideDistance                    0
# roadKills                       0
# swimDistance                    0
# teamKills                       0
# vehicleDestroys                 0
# walkDistance                61.38
# weaponsAcquired                 2
# ...

# %%
x1=pubg['kills']>=48 
pubg[x1]
#Some players have more then 48 kills but 0 heals,how?It's suspicious
# Out:
#                      Id         groupId         matchId  assists  boosts  \
# 156599   746aa7eabf7c86  5723e7d8250da3  f900de1ec39fa5       21       0
# 334400   810f2379261545  7f3e493ee71534  f900de1ec39fa5       20       0
# 672993   da31f191ace8ed  ce9a3c4950a8f2  17dea22cefe62a       10       0
# 770454   2ade4369bccd12  9f9e64a3db8384  e024bf51bf1799       12       0
# 797111   7f3edd982813e6  10a20932a5cf8f  cfa2775c9ef944        6       0
# 1248348  80ac0bbf58bfaf  1e54ab4540a337  08e4c9e6c033e2        5       0
# 1454065  c47bd86daa3de6  4df3e348b910d8  3ebf1bf8bc6bae        2       2
# 1462706  be4ff9afaa5bb1  abb73dd57619fa  f900de1ec39fa5       22       0
# 1491277  1f6ceaa5140fb6  dc2fef63e14d5c  f900de1ec39fa5       15       0
# 2020831  9b5bcc3a3dd42a  bdd2cf09863501  6bf647ecee30da        2       0
# 2601666  436d1530e9eb00  5c974c2bb9d9f0  fe7043ee6221c8        5       0
# 2914453  d10322b281014b  a999807e7f7780  904cecf36217df        2      10
# ...

# %%
x_train1=x_train[x_train['kills']<=40]
x_test1=x_test[x_test['kills']<=40]

# %%
len(x_train1)
# Out:
# 3112857

# %%
len(x_train)
# Out:
# 3112876

# %%
x_train1=x_train1[x_train1['longestKill']<6766]#Cause the 1km sniper kill is not possible in this game
x_test1=x_test1[x_test1['longestKill']<6766]

# %%
len(x_train1)#So,there were aim hack cheaters got eliminated
# Out:
# 3112857

# %%
#Speed hacks:Going from one side of map to other in seconds 
k=x_train1['walkDistance'].astype(float)
plt.hist(k,bins=100)
plt.show()

# %%
x_train1=x_train1[x_train1['walkDistance']<=11000]
x_test1=x_test1[x_test1['walkDistance']<=11000]
len(x_train1)
# Out:
# 3112794

# %%
k=x_train1['rideDistance'].astype(float)
plt.hist(k,bins=100,rwidth=100)
plt.show()

# %%
x_train1=x_train1[x_train1['rideDistance']<=10000]
x_test1=x_test1[x_test1['rideDistance']<=10000]

len(x_train1)
# Out:
# 3108361

# %%
#Items and Supplies Hack
k=x_train1['weaponsAcquired'].astype(float)
plt.hist(k,bins=100,rwidth=100)
plt.show()

# %%
#is the weapon acquires>60 possible?If player moved distance,like to spawn island but can be knocked by blue circle easily
#from the graph most are below 60
x_train1=x_train1[x_train1['weaponsAcquired']<60]
x_test1=x_test1[x_test1['weaponsAcquired']<60]

len(x_train1)
# Out:
# 3108299

# %%
k=x_train1['heals'].astype(float)
plt.hist(k,bins=100,rwidth=100)
plt.show()

# %%
#can we say those who have heals>40 and kills>40 really lucky 
x_train1=x_train1[x_train1['heals']<50]
x_test1=x_test1[x_test1['heals']<50]

len(x_train1)
# Out:
# 3108285

# %%
print('No of assumed hackers:{} in a data set of {} players'.format(len(x_train)-len(x_train1),len(x_train)))
# Out:
# No of assumed hackers:4591 in a data set of 3112876 players

# %%
len(x_train1)
# Out:
# 3108267

# %%
c1=(x_train1['walkDistance']==0) & (x_train1['kills']==0)
c2=(x_train1['walkDistance']>0) & (x_train1['kills']==0)
c3=(x_train1['walkDistance']>0) & (x_train1['kills']>0)

#If the player has walked 0 distance but has more than zero kills that's suspicious ,so we exclude those players

x_train2= x_train1[c1|c2|c3]

# %%
c1=(x_test1['walkDistance']==0) & (x_test1['kills']==0)
c2=(x_test1['walkDistance']>0) & (x_test1['kills']==0)
c3=(x_test1['walkDistance']>0) & (x_test1['kills']>0)

#If the player has walked 0 distance but has more than zero kills that's suspicious ,so we exclude those players

x_test2= x_test1[c1|c2|c3]

# %%
len(x_train2)
# Out:
# 3107216

# %%
len(x_test2)
# Out:
# 1331677

# %%
len(y_test)
# Out:
# 1334090

# %%
len(df22)
# Out:
# 1334090

# %%
print('Total No of assumed hackers:{} in a data set of {} players'.format(len(x_train)-len(x_train2),len(x_train)))
# Out:
# Total No of assumed hackers:5660 in a data set of 3112876 players

# %%
y_train
# Out:
# 802633     0.6071
# 2736325    0.1429
# 2940094    0.9375
# 1297467    0.9643
# 4061634    0.2826
# 388851     0.6538
# 2811829    0.2800
# 2267717    0.1538
# 1333841    0.5185
# 1177546    0.3448
# 599345     0.5567
# 2816910    0.6809
# 4309672    0.1778
# 164047     0.6250
# 2729144    1.0000
# 2553648    0.0357
# 2562240    1.0000
# 909027     0.2692
# 1750536    1.0000
# 4102835    0.4681
# 2718556    0.7586
# 1164540    0.1290
# 4185477    0.6042
# 1138594    0.1087
# 2025916    0.0000
# 1384097    0.7037
# 400529     0.1111
# 3077029    0.8750
# 2280096    0.8929
# 1903976    0.8085
#             ...
# 1884874    0.3478
# 1563167    0.0638
# 3449376    0.7407
# 1133241    0.0000
# 3329289    0.4681
# 4064029    0.7872
# 2327283    0.0000
# 556209     0.6316
# 1419224    1.0000
# 4087907    0.5357
# 441170     0.1071
# 4065728    0.0444
# 3743151    0.4074
# 3491838    0.7609
# 532165     0.6667
# 2527987    0.4444
# 2951283    0.6071
# 3107661    0.2917
# 606745     0.0000
# ...

# %%
x_train2
# Out:
#                      Id         groupId         matchId  assists  boosts  \
# 802633   c098ac42f9a222  8592abdb5452d5  7e076894f6b6b7        0       0
# 2736325  8aaffd5277c774  39a53d1b729105  d17199d85852f7        0       0
# 2940094  ac5989bd615c87  6ec631de07ea5c  f1dd37adfb4dfd        0       0
# 1297467  67a501f32dbfa1  a3963283c01b96  9d5475325646b5        1       6
# 4061634  d1572fa5775c57  3035a1e0615988  223729a30fd2a0        0       0
# 388851   e8e182102fde8d  1e7d25ab875795  d526999c4be49b        0       0
# 2811829  9b250f693d1756  51420ee8cbf05a  c8b6a89c5d54da        1       0
# 2267717  40dd4be2a81622  f4bf3a1d7e8bf4  4ee30fa2a713ee        1       0
# 1333841  e7ba56d410226e  c2e9eff3a96a95  40855ac0f833ed        1       0
# 1177546  b57bcfa52328dc  ae14064a54ad26  3c71fe9ee54baa        0       0
# 599345   97d933cc83a60f  bfc9edc0da4144  a548d87526a371        0       0
# 2816910  f21788c290754c  40b922a9e749c6  6229b602d8ae9e        0       2
# ...

# %%
print(x_train2.loc[2811829])
# Out:
# Id                 9b250f693d1756
# groupId            51420ee8cbf05a
# matchId            c8b6a89c5d54da
# assists                         1
# boosts                          0
# damageDealt                   100
# DBNOs                           0
# headshotKills                   0
# heals                           0
# killPlace                      28
# killPoints                      0
# kills                           1
# killStreaks                     1
# longestKill                 7.353
# matchDuration                1946
# matchType               squad-fpp
# maxPlace                       26
# numGroups                      26
# rankPoints                   1390
# revives                         1
# rideDistance                    0
# roadKills                       0
# swimDistance                    0
# teamKills                       0
# vehicleDestroys                 0
# walkDistance                405.8
# weaponsAcquired                 5
# ...

# %%
print(y_train.loc[2811829])
# Out:
# 0.28

# %%
print(pubg.loc[2811829])
# Out:
# Id                 9b250f693d1756
# groupId            51420ee8cbf05a
# matchId            c8b6a89c5d54da
# assists                         1
# boosts                          0
# damageDealt                   100
# DBNOs                           0
# headshotKills                   0
# heals                           0
# killPlace                      28
# killPoints                      0
# kills                           1
# killStreaks                     1
# longestKill                 7.353
# matchDuration                1946
# matchType               squad-fpp
# maxPlace                       26
# numGroups                      26
# rankPoints                   1390
# revives                         1
# rideDistance                    0
# roadKills                       0
# swimDistance                    0
# teamKills                       0
# vehicleDestroys                 0
# walkDistance                405.8
# weaponsAcquired                 5
# ...

# %%
len(y_train)
# Out:
# 3112876

# %%
f,ax=plt.subplots(figsize=(15,15))
sns.heatmap(pubg.corr(),annot=True,linewidths=.5,fmt='.1f',ax=ax)
plt.show()

# %%
#Out of 26 only 15 features are positively correlated with winPlacePerc
len(x_train2)
df=x_train2

# %%
from scipy import stats
from sklearn.cluster import KMeans
import numpy as np

# %%
df=x_train2
clmns=[ 'assists', 'boosts', 'damageDealt','DBNOs','headshotKills','heals','kills','killStreaks','longestKill','revives','rideDistance','swimDistance','vehicleDestroys','walkDistance','weaponsAcquired','killPlace',]
df_tr_std=stats.zscore(df[clmns])
kmeans=KMeans(n_clusters=9,random_state=0).fit(df_tr_std)
labels=kmeans.labels_
df['clusters']=labels
clmns.extend(['clusters'])
# Out:
# C:\python_progs\anaconda\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
print (df[clmns].groupby(['clusters']).mean())#This is for k=9 we see basing on mean how the clusters have been formed 
#like for cluster 0 it's mean for kill is higher than that of cluster 1,same for Longest kill mean
#So the cluster 1 is more based on kills
# Out:
#            assists    boosts  damageDealt     DBNOs  headshotKills     heals  \
# clusters
# 0         0.268906  2.318328   146.652494  0.623623       0.266244  2.899734
# 1         0.140182  0.483302   161.311808  0.945548       0.312783  0.672159
# 2         1.097434  4.291045   676.758016  3.898997       1.919311  4.402268
# 3         0.064621  0.091128    32.683074  0.113026       0.000000  0.157050
# 4         0.273687  2.389670   110.690709  0.465686       0.106345  3.937086
# 5         0.619398  2.818902   285.289455  1.423747       0.481959  3.302016
# 6         0.190419  1.183236    55.228517  0.161632       0.003875  1.366928
# 7         0.631031  2.521149   249.959753  1.546853       0.387924  3.543779
# 8         0.519340  3.081899   289.994112  1.309449       0.608096  3.219276
#
#              kills  killStreaks  longestKill   revives  rideDistance  \
# clusters
# 0         1.099165     0.638124    36.224155  0.189473   1193.168915
# ...

# %%
df.head(10)
# Out:
#                      Id         groupId         matchId  assists  boosts  \
# 802633   c098ac42f9a222  8592abdb5452d5  7e076894f6b6b7        0       0
# 2736325  8aaffd5277c774  39a53d1b729105  d17199d85852f7        0       0
# 2940094  ac5989bd615c87  6ec631de07ea5c  f1dd37adfb4dfd        0       0
# 1297467  67a501f32dbfa1  a3963283c01b96  9d5475325646b5        1       6
# 4061634  d1572fa5775c57  3035a1e0615988  223729a30fd2a0        0       0
# 388851   e8e182102fde8d  1e7d25ab875795  d526999c4be49b        0       0
# 2811829  9b250f693d1756  51420ee8cbf05a  c8b6a89c5d54da        1       0
# 2267717  40dd4be2a81622  f4bf3a1d7e8bf4  4ee30fa2a713ee        1       0
# 1333841  e7ba56d410226e  c2e9eff3a96a95  40855ac0f833ed        1       0
# 1177546  b57bcfa52328dc  ae14064a54ad26  3c71fe9ee54baa        0       0
#
#          damageDealt  DBNOs  headshotKills  heals  killPlace    ...     \
# 802633          0.00      0              0      0         56    ...
# ...

# %%
len(df)
# Out:
# 3107200

# %%
y_train.head(10)
# Out:
# 802633     0.6071
# 2736325    0.1429
# 2940094    0.9375
# 1297467    0.9643
# 4061634    0.2826
# 388851     0.6538
# 2811829    0.2800
# 2267717    0.1538
# 1333841    0.5185
# 1177546    0.3448
# Name: winPlacePerc, dtype: float64

# %%
df1=df
y_t=y_train
df11=x_test2
y_t1=y_test

# %%
df2=df1.merge(y_t.to_frame(), how='inner', left_index=True, right_index=True)

# %%
df22=df11.merge(y_t1.to_frame(), how='inner', left_index=True, right_index=True)

# %%
df2['winPlacePerc']
# Out:
# 802633     0.6071
# 2736325    0.1429
# 2940094    0.9375
# 1297467    0.9643
# 4061634    0.2826
# 388851     0.6538
# 2811829    0.2800
# 2267717    0.1538
# 1333841    0.5185
# 1177546    0.3448
# 599345     0.5567
# 2816910    0.6809
# 4309672    0.1778
# 164047     0.6250
# 2729144    1.0000
# 2553648    0.0357
# 2562240    1.0000
# 909027     0.2692
# 1750536    1.0000
# 4102835    0.4681
# 2718556    0.7586
# 1164540    0.1290
# 4185477    0.6042
# 1138594    0.1087
# 2025916    0.0000
# 1384097    0.7037
# 400529     0.1111
# 3077029    0.8750
# 2280096    0.8929
# 1903976    0.8085
#             ...
# 1884874    0.3478
# 1563167    0.0638
# 3449376    0.7407
# 1133241    0.0000
# 3329289    0.4681
# 4064029    0.7872
# 2327283    0.0000
# 556209     0.6316
# 1419224    1.0000
# 4087907    0.5357
# 441170     0.1071
# 4065728    0.0444
# 3743151    0.4074
# 3491838    0.7609
# 532165     0.6667
# 2527987    0.4444
# 2951283    0.6071
# 3107661    0.2917
# 606745     0.0000
# ...

# %%
df.columns
# Out:
# Index(['Id', 'groupId', 'matchId', 'assists', 'boosts', 'damageDealt', 'DBNOs',
#        'headshotKills', 'heals', 'killPlace', 'killPoints', 'kills',
#        'killStreaks', 'longestKill', 'matchDuration', 'matchType', 'maxPlace',
#        'numGroups', 'rankPoints', 'revives', 'rideDistance', 'roadKills',
#        'swimDistance', 'teamKills', 'vehicleDestroys', 'walkDistance',
#        'weaponsAcquired', 'winPoints', 'clusters'],
#       dtype='object')

# %%
len(df2)
# Out:
# 3107200

# %%
grp1=df2[df2['clusters']==7]

# %%
print(grp1['winPlacePerc'].mean())
# Out:
# 0.7320168762833549

# %%
for i in range(0,5):#for 6 clusters
    grp2=df2[df2['clusters']==i]
    print('The mean for winPlacePerc for cluster number {} is {:.4f} and 99% of people have winPlacePerc as {:.4f}'.format(i,grp2['winPlacePerc'].mean(),grp2['winPlacePerc'].quantile(0.99)))
# Out:
# The mean for winPlacePerc for cluster number 0 is 0.2203 and 99% of people have winPlacePerc as 0.8085
# The mean for winPlacePerc for cluster number 1 is 0.8599 and 99% of people have winPlacePerc as 1.0000
# The mean for winPlacePerc for cluster number 2 is 0.4039 and 99% of people have winPlacePerc as 0.9615
# The mean for winPlacePerc for cluster number 3 is 0.8019 and 99% of people have winPlacePerc as 1.0000
# The mean for winPlacePerc for cluster number 4 is 0.7369 and 99% of people have winPlacePerc as 1.0000

# %%
for i in range(0,7):#for 7 clusters
    grp2=df2[df2['clusters']==i]
    print('The mean for winPlacePerc for cluster number {} is {:.4f} and 99% of people have winPlacePerc as {:.4f} and mode is {}'.format(i,grp2['winPlacePerc'].mean(),grp2['winPlacePerc'].quantile(0.99),stats.mode(grp2['winPlacePerc'])))
# Out:
# The mean for winPlacePerc for cluster number 0 is 0.2203 and 99% of people have winPlacePerc as 0.8085 and mode is ModeResult(mode=array([0.]), count=array([138356]))
# The mean for winPlacePerc for cluster number 1 is 0.8599 and 99% of people have winPlacePerc as 1.0000 and mode is ModeResult(mode=array([1.]), count=array([29953]))
# The mean for winPlacePerc for cluster number 2 is 0.4039 and 99% of people have winPlacePerc as 0.9615 and mode is ModeResult(mode=array([0.]), count=array([13216]))
# The mean for winPlacePerc for cluster number 3 is 0.8019 and 99% of people have winPlacePerc as 1.0000 and mode is ModeResult(mode=array([1.]), count=array([35999]))
# The mean for winPlacePerc for cluster number 4 is 0.7369 and 99% of people have winPlacePerc as 1.0000 and mode is ModeResult(mode=array([1.]), count=array([6921]))
# ...

# %%
for i in range(0,8):#for 8 clusters
    grp2=df2[df2['clusters']==i]
    print('The mean for winPlacePerc for cluster number {} is {:.4f} and 99% of people have winPlacePerc as {:.4f} and mode is {}'.format(i,grp2['winPlacePerc'].mean(),grp2['winPlacePerc'].quantile(0.99),stats.mode(grp2['winPlacePerc'])))
# Out:
# The mean for winPlacePerc for cluster number 0 is 0.2203 and 99% of people have winPlacePerc as 0.8085 and mode is ModeResult(mode=array([0.]), count=array([138356]))
# The mean for winPlacePerc for cluster number 1 is 0.8599 and 99% of people have winPlacePerc as 1.0000 and mode is ModeResult(mode=array([1.]), count=array([29953]))
# The mean for winPlacePerc for cluster number 2 is 0.4039 and 99% of people have winPlacePerc as 0.9615 and mode is ModeResult(mode=array([0.]), count=array([13216]))
# The mean for winPlacePerc for cluster number 3 is 0.8019 and 99% of people have winPlacePerc as 1.0000 and mode is ModeResult(mode=array([1.]), count=array([35999]))
# The mean for winPlacePerc for cluster number 4 is 0.7369 and 99% of people have winPlacePerc as 1.0000 and mode is ModeResult(mode=array([1.]), count=array([6921]))
# ...

# %%
from scipy import stats
for i in range(0,9):#for 9 clusters
    grp2=df2[df2['clusters']==i]
    print('The mean for winPlacePerc for cluster number {} is {:.4f} and 99% of people have winPlacePerc as {:.4f} and mode is {}'.format(i,grp2['winPlacePerc'].mean(),grp2['winPlacePerc'].quantile(0.99),stats.mode(grp2['winPlacePerc'])))
# Out:
# The mean for winPlacePerc for cluster number 0 is 0.7903 and 99% of people have winPlacePerc as 1.0000 and mode is ModeResult(mode=array([1.]), count=array([1138]))
# The mean for winPlacePerc for cluster number 1 is 0.3904 and 99% of people have winPlacePerc as 0.9583 and mode is ModeResult(mode=array([0.]), count=array([13431]))
# The mean for winPlacePerc for cluster number 2 is 0.8639 and 99% of people have winPlacePerc as 1.0000 and mode is ModeResult(mode=array([1.]), count=array([28578]))
# The mean for winPlacePerc for cluster number 3 is 0.2174 and 99% of people have winPlacePerc as 0.8077 and mode is ModeResult(mode=array([0.]), count=array([138068]))
# The mean for winPlacePerc for cluster number 4 is 0.7314 and 99% of people have winPlacePerc as 1.0000 and mode is ModeResult(mode=array([1.]), count=array([6147]))
# ...

# %%
#As for the clusters a pattern is observed here the mostly we have 2 clusters whose mean WinPerPlace is less than 0.5 
#we found that it's mode have most values in 0. whereas above 0.5 mean has 1. mode values 
#As for the 99 quantile also there is 1.0 for those clusters above mean 0.5 
#So at 9 an interesting result of mode 0.5 was found out,assuming it to be average players
#These above distinctions were clearly shown for k=7 to 9
#But then comparing k=8 for 90 quantile below to see any changes

# %%
for i in range(0,8):#for 8 clusters
    grp2=df2[df2['clusters']==i]
    print('The mean for winPlacePerc for cluster number {} is {:.4f} and 90% of people have winPlacePerc as {:.4f} and mode is {}'.format(i,grp2['winPlacePerc'].mean(),grp2['winPlacePerc'].quantile(0.90),stats.mode(grp2['winPlacePerc'])))
# Out:
# The mean for winPlacePerc for cluster number 0 is 0.2203 and 90% of people have winPlacePerc as 0.4792 and mode is ModeResult(mode=array([0.]), count=array([138356]))
# The mean for winPlacePerc for cluster number 1 is 0.8599 and 90% of people have winPlacePerc as 1.0000 and mode is ModeResult(mode=array([1.]), count=array([29953]))
# The mean for winPlacePerc for cluster number 2 is 0.4039 and 90% of people have winPlacePerc as 0.7407 and mode is ModeResult(mode=array([0.]), count=array([13216]))
# The mean for winPlacePerc for cluster number 3 is 0.8019 and 90% of people have winPlacePerc as 0.9792 and mode is ModeResult(mode=array([1.]), count=array([35999]))
# The mean for winPlacePerc for cluster number 4 is 0.7369 and 90% of people have winPlacePerc as 0.9579 and mode is ModeResult(mode=array([1.]), count=array([6921]))
# ...

# %%
#So,90% quantile gave further good results and out of two above mentioned clusters(mean<0.5) 
#we have 90% players having 0.5 to 0.7
#Rest other clusters have higher number of good player(ask those for chicken treat) having 90% players in range 0.9-1.0
#Even mode results of 1. also matches with the results

# %%
for i in range(0,6):#for 6 clusters
    grp2=df2[df2['clusters']==i]
    print('The mean for winPlacePerc for cluster number {} is {:.4f} and 99% of people have winPlacePerc as {:.4f} and mode is {}'.format(i,grp2['winPlacePerc'].mean(),grp2['winPlacePerc'].quantile(0.99),stats.mode(grp2['winPlacePerc'])))
# Out:
# The mean for winPlacePerc for cluster number 0 is 0.2203 and 99% of people have winPlacePerc as 0.8085 and mode is ModeResult(mode=array([0.]), count=array([138356]))
# The mean for winPlacePerc for cluster number 1 is 0.8599 and 99% of people have winPlacePerc as 1.0000 and mode is ModeResult(mode=array([1.]), count=array([29953]))
# The mean for winPlacePerc for cluster number 2 is 0.4039 and 99% of people have winPlacePerc as 0.9615 and mode is ModeResult(mode=array([0.]), count=array([13216]))
# The mean for winPlacePerc for cluster number 3 is 0.8019 and 99% of people have winPlacePerc as 1.0000 and mode is ModeResult(mode=array([1.]), count=array([35999]))
# The mean for winPlacePerc for cluster number 4 is 0.7369 and 99% of people have winPlacePerc as 1.0000 and mode is ModeResult(mode=array([1.]), count=array([6921]))
# ...

# %%
df=x_train2
clmns=[ 'assists', 'boosts', 'damageDealt','DBNOs','headshotKills','heals','kills','killStreaks','longestKill','revives','rideDistance','swimDistance','vehicleDestroys','walkDistance','weaponsAcquired','killPlace']
df_tr_std=stats.zscore(df[clmns])
for k in range(5,14):
    k_model=KMeans(n_clusters=k,random_state=1).fit(df_tr_std)
    #labels=k_model labels
    inertia=k_model.inertia_
    print("k:",k,"cost:",inertia)
# Out:
# k: 5 cost: 27491195.52645065
# k: 6 cost: 25855609.63146321
# k: 7 cost: 24121784.87297323
# k: 8 cost: 22984525.30858146
# k: 9 cost: 21999939.263118166
# k: 10 cost: 21262980.797828633
# k: 11 cost: 20612224.79839398
# k: 12 cost: 19976745.717332397
# k: 13 cost: 19365551.32852287

# %%
from sklearn.metrics import silhouette_score

# %%
df=x_train2
clmns=[ 'assists', 'boosts', 'damageDealt','DBNOs','headshotKills','heals','kills','killStreaks','longestKill','revives','rideDistance','swimDistance','vehicleDestroys','walkDistance','weaponsAcquired','killPlace']
df_tr_std=stats.zscore(df[clmns])
for k in range(8,10):
    k_model=KMeans(n_clusters=k,random_state=1)
    labels=k_model.fit_predict(df_tr_std)
    sil_avg=silhouette_score(df_tr_std,labels)
    print("k:",k," Silhouette average:",sil_avg)

# %%
df=x_train2
clmns=[ 'assists', 'boosts', 'damageDealt','DBNOs','headshotKills','heals','kills','killStreaks','longestKill','revives','rideDistance','swimDistance','vehicleDestroys','walkDistance','weaponsAcquired','killPlace']
df_tr_std=stats.zscore(df[clmns])

# %%
k_model=KMeans(n_clusters=6,random_state=1).fit(df_tr_std)
inertia1=k_model.inertia_

# %%
rand1=np.random.random_sample(size=df_tr_std.shape)

# %%
len(rand1)
# Out:
# 3107200

# %%
km=KMeans(6)

#inertia2=km.inertia_

# %%
km.fit(rand1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-81-fbb3f8c389b6> in <module>
# ----> 1 km.fit(rand1)
#
# C:\python_progs\anaconda\lib\site-packages\sklearn\cluster\k_means_.py in fit(self, X, y, sample_weight)
#     969                 tol=self.tol, random_state=random_state, copy_x=self.copy_x,
#     970                 n_jobs=self.n_jobs, algorithm=self.algorithm,
# --> 971                 return_n_iter=True)
#     972         return self
#     973
#
# C:\python_progs\anaconda\lib\site-packages\sklearn\cluster\k_means_.py in k_means(X, n_clusters, sample_weight, init, precompute_distances, n_init, max_iter, verbose, tol, random_state, copy_x, n_jobs, algorithm, return_n_iter)
#     378                 verbose=verbose, precompute_distances=precompute_distances,
#     379                 tol=tol, x_squared_norms=x_squared_norms,
# ...

# %%
inertia2=km.inertia_

# %%
gap=np.log(np.mean(inertia2))-np.log(inertia1)

# %%
print("Gap for k=",5,"is:",gap)
# Out:
# Gap for k= 5 is: -0.027865369547939167

# %%
print("Gap for k=",6,"is:",gap)
# Out:
# Gap for k= 6 is: 0.0002506345096797702

# %%
print("Gap for k=",7,"is:",gap)
# Out:
# Gap for k= 7 is: 0.038952601402410636

# %%
print("Gap for k=",8,"is:",gap)
# Out:
# Gap for k= 8 is: 0.06001263455011241

# %%
print("Gap for k=",9,"is:",gap)
# Out:
# Gap for k= 9 is: 0.10379411878172462

# %%
print("Gap for k=",10,"is:",gap)
# Out:
# Gap for k= 10 is: 0.09050138364465354

# %%
import matplotlib.pyplot as plt
plt.plot([5,6,7,8,9,10],[10-0.027865369547939167,10+0.0002506345096797702,10+0.038952601402410636,10+0.06001263455011241,10+0.10379411878172462,10+0.09050138364465354],color='black',linewidth=2)
plt.show()

# %%
k1=[26735717.9188823,24988463.584453616,23515611.923082847,22384675.917633492,21392705.06601217,20645273.20872663]

# %%
inertia1=21262980.797828633
gap=np.log(np.mean(k1))-np.log(inertia1)

# %%
from sklearn.decomposition import PCA
clmns=[ 'assists', 'boosts', 'damageDealt','DBNOs','headshotKills','heals','kills','killStreaks','longestKill','revives','rideDistance','swimDistance','vehicleDestroys','walkDistance','weaponsAcquired','killPlace']
ch=df[clmns]
ch
# Out:
#          assists  boosts  damageDealt  DBNOs  headshotKills  heals  kills  \
# 802633         0       0         0.00      0              0      0      0
# 2736325        0       0         0.00      0              0      0      0
# 2940094        0       0       107.90      0              0      0      0
# 1297467        1       6       151.60      0              0     18      1
# 4061634        0       0        81.27      0              0      0      0
# 388851         0       0         0.00      0              0      0      0
# 2811829        1       0       100.00      0              0      0      1
# 2267717        1       0       114.20      1              0      0      2
# 1333841        1       0        30.10      0              0      0      0
# 1177546        0       0         0.00      0              0      0      0
# 599345         0       0       100.00      0              0      0      1
# 2816910        0       2        23.40      0              0      0      0
# ...

# %%
pca=PCA(n_components=5)
pca_2d=pca.fit_transform(ch)
pca_2d
# Out:
# array([[-2.91327717e+02,  6.83715975e+02, -1.58815155e+02,
#         -5.51045506e+00, -7.57971728e+00],
#        [-1.04752400e+03, -6.50005282e+02, -6.85191770e+01,
#          5.50878091e+00, -5.10449150e-01],
#        [-9.10938684e+02, -4.09639841e+02,  2.47521621e+01,
#         -1.07578644e+01, -7.87588545e-01],
#        ...,
#        [-6.67962260e+02,  1.75108324e+01,  2.87012270e+02,
#         -3.65105033e+01, -1.03071730e+00],
#        [ 7.55739924e+02,  2.52822475e+03,  1.34669574e+02,
#          1.32719146e+01, -1.48050383e+01],
#        [ 3.89879690e+03, -4.19130587e+02, -2.36281532e+02,
#         -2.38792147e+01, -1.26789335e+01]])

# %%
new1=x_train2.head(1000)
new1
# Out:
#                      Id         groupId         matchId  assists  boosts  \
# 802633   c098ac42f9a222  8592abdb5452d5  7e076894f6b6b7        0       0
# 2736325  8aaffd5277c774  39a53d1b729105  d17199d85852f7        0       0
# 2940094  ac5989bd615c87  6ec631de07ea5c  f1dd37adfb4dfd        0       0
# 1297467  67a501f32dbfa1  a3963283c01b96  9d5475325646b5        1       6
# 4061634  d1572fa5775c57  3035a1e0615988  223729a30fd2a0        0       0
# 388851   e8e182102fde8d  1e7d25ab875795  d526999c4be49b        0       0
# 2811829  9b250f693d1756  51420ee8cbf05a  c8b6a89c5d54da        1       0
# 2267717  40dd4be2a81622  f4bf3a1d7e8bf4  4ee30fa2a713ee        1       0
# 1333841  e7ba56d410226e  c2e9eff3a96a95  40855ac0f833ed        1       0
# 1177546  b57bcfa52328dc  ae14064a54ad26  3c71fe9ee54baa        0       0
# 599345   97d933cc83a60f  bfc9edc0da4144  a548d87526a371        0       0
# 2816910  f21788c290754c  40b922a9e749c6  6229b602d8ae9e        0       2
# ...

# %%
df1=x_train2.head(1000)
clmns=[ 'assists', 'boosts', 'damageDealt','DBNOs','headshotKills','heals','kills','killStreaks','longestKill','revives','rideDistance','swimDistance','vehicleDestroys','walkDistance','weaponsAcquired','killPlace',]
df_tr_std=stats.zscore(df1[clmns])
kmeans=KMeans(n_clusters=9,random_state=0).fit(df_tr_std)
labels=kmeans.labels_
#df['clusters']=labels
#clmns.extend(['clusters'])
labels
# Out:
# array([0, 5, 5, 2, 5, 5, 1, 1, 5, 5, 1, 0, 5, 4, 4, 5, 8, 5, 8, 0, 1, 5,
#        0, 5, 5, 1, 5, 0, 4, 8, 0, 8, 2, 5, 4, 5, 1, 5, 5, 1, 1, 5, 4, 0,
#        5, 1, 1, 0, 5, 1, 5, 5, 1, 2, 5, 8, 4, 1, 0, 1, 0, 0, 0, 5, 5, 4,
#        5, 5, 1, 5, 0, 1, 0, 0, 5, 1, 1, 1, 5, 5, 1, 4, 5, 5, 5, 8, 1, 1,
#        0, 5, 1, 0, 8, 1, 5, 5, 1, 1, 1, 1, 5, 1, 5, 4, 5, 5, 2, 5, 5, 0,
#        5, 0, 8, 5, 8, 0, 5, 0, 5, 4, 1, 0, 4, 1, 6, 1, 0, 5, 2, 5, 5, 4,
#        1, 0, 5, 5, 1, 1, 5, 1, 8, 5, 5, 0, 2, 8, 5, 0, 0, 1, 0, 6, 1, 1,
#        8, 5, 8, 0, 4, 1, 2, 1, 1, 0, 1, 4, 2, 5, 0, 0, 4, 0, 5, 1, 5, 1,
#        1, 1, 0, 4, 0, 0, 5, 0, 5, 1, 5, 5, 5, 0, 5, 5, 5, 5, 7, 5, 1, 0,
#        4, 0, 0, 1, 3, 0, 5, 5, 5, 5, 1, 5, 5, 1, 5, 1, 0, 1, 0, 1, 0, 5,
#        4, 6, 5, 1, 4, 4, 0, 5, 4, 1, 0, 0, 7, 5, 5, 5, 0, 5, 1, 6, 5, 8,
#        2, 0, 0, 1, 1, 5, 0, 1, 8, 5, 5, 0, 0, 7, 1, 1, 8, 4, 1, 5, 4, 4,
#        1, 5, 0, 5, 8, 1, 1, 5, 1, 2, 1, 5, 1, 4, 4, 1, 5, 5, 1, 8, 0, 1,
# ...

# %%
y1=df.head(1000)
np.mean(labels-y1['clusters'])**2
# Out:
# 0.5929

# %%
x_test
# Out:
#                      Id         groupId         matchId  assists  boosts  \
# 1662101  f2cc6d85a8486f  d21616f4227644  69aa635ee59233        0       0
# 1104834  930fcba22f4672  7d2c5e1972301e  c3bf6e6e2c4a7d        0       1
# 2221450  7a81fd3908c613  e31bab912a2212  aaed9b0508353c        0       2
# 85169    ecea9ba3aa5ca7  1e083707920a65  8b2240a0beb03d        0       0
# 1018615  0297a8a7b5fe67  1abdadeaabfc40  44a1a07a45d86f        1       0
# 3845461  f63ef7265c04a0  b58e6d61382875  3462330f7fd5ec        0       0
# 4299214  cd80111f8d04de  f207767f5499a0  3e0eb2a8d6e12f        0       0
# 3167712  a60bbd614a32e0  bf5bffae964772  c18329068aef36        0       0
# 423023   af80d6f2a8b9c9  89418a119eb64c  74aa15003c69b6        1       3
# 1203082  67e06ccbf22101  afb3b64bc3697b  9ec6c15695fe9a        0       0
# 464583   3392f7499669d9  4c58ed564e8834  b33e9339adebac        0       3
# 495853   403f49920eb989  9b2031617b9c9d  5d2ca44ce5bc17        0       0
# ...

# %%
print (df[clmns].groupby(['clusters']).mean())
# Out:
#            assists    boosts  damageDealt     DBNOs  headshotKills     heals  \
# clusters
# 0         0.134615  0.307692   153.461122  0.993590       0.333333  0.493590
# 1         0.271930  1.982456   266.894123  1.482456       0.535088  2.377193
# 2         0.071782  0.121287    32.280173  0.116337       0.000000  0.170792
# 3         0.629630  4.574074   394.210000  1.777778       0.814815  5.444444
# 4         0.500000  3.416667   335.139167  1.250000       0.583333  5.916667
# 5         0.168605  1.610465    53.398437  0.174419       0.023256  2.209302
# 6         1.278689  2.770492   255.074426  1.393443       0.393443  4.459016
# 7         0.000000  1.250000   141.725000  0.500000       0.250000  2.250000
# 8         1.304348  4.695652   776.465217  4.434783       2.130435  4.086957
#
#              kills  killStreaks  longestKill   revives  rideDistance  \
# clusters
# 0         1.294872     1.141026    18.080921  0.108974     77.998718
# ...

# %%
from sklearn import linear_model
reg=linear_model.LinearRegression()
clmns1=['assists', 'boosts', 'damageDealt', 'DBNOs', 'headshotKills', 'heals', 'kills', 'killStreaks', 'longestKill', 'revives', 'rideDistance', 'swimDistance', 'vehicleDestroys', 'walkDistance', 'weaponsAcquired', 'killPlace', ]

# %%
reg.fit(df[clmns1],df2['winPlacePerc'])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
reg.coef_
# Out:
# array([ 1.35374168e-02,  1.80163906e-02,  7.67178967e-05, -1.76089387e-02,
#         1.53048636e-03, -7.54379553e-05, -9.21114828e-03, -1.38169935e-01,
#        -1.58279248e-05,  9.57323214e-03,  7.08932956e-06,  1.41451202e-04,
#        -6.02464729e-03,  1.07895206e-04,  1.00165901e-02, -7.37660668e-03])

# %%
a=reg.predict(x_test[clmns1])
a
# Out:
# array([0.70502651, 0.35686438, 0.69418196, ..., 0.89312434, 0.72801016,
#        0.29409505])

# %%
a[1]
# Out:
# 0.3568643801096116

# %%
y_test
# Out:
# 1662101    0.4783
# 1104834    0.3846
# 2221450    0.9167
# 85169      0.0769
# 1018615    0.4074
# 3845461    0.0000
# 4299214    0.2692
# 3167712    0.1765
# 423023     0.6735
# 1203082    0.3261
# 464583     0.8969
# 495853     0.2128
# 2857774    0.2222
# 2340432    0.0000
# 3446457    0.3462
# 359987     1.0000
# 2855709    0.8936
# 2252982    0.7755
# 2976030    0.6452
# 672967     0.9655
# 1239258    0.6667
# 3994852    0.8061
# 3135627    0.9792
# 2093266    0.2340
# 492769     0.1277
# 2421987    0.7174
# 3455287    0.5870
# 3080802    0.9362
# 265953     0.8889
# 1414044    0.8846
#             ...
# 3074674    0.3571
# 2228566    0.1250
# 168306     0.6786
# 1351783    0.1111
# 2154029    0.0800
# 2805498    0.1154
# 3387166    0.2500
# 3335497    0.4444
# 1250847    0.8409
# 4203726    0.9259
# 1117983    0.8846
# 3880412    0.0741
# 4120140    0.1860
# 2686860    0.0400
# 3883874    0.1111
# 1203108    0.4074
# 3967318    0.5625
# 4309162    0.4468
# 2619583    0.1020
# ...

# %%
#mean square error
np.mean(a-y_test)**2
# Out:
# 1.5130942373609186e-08

# %%
from sklearn.linear_model import Lasso
lasso=Lasso(alpha=0.1)
lasso_coeff=lasso.fit(df[clmns1],df2['winPlacePerc']).coef_

# %%
import matplotlib.pyplot as plt
_=plt.plot(range(len(clmns1)),lasso_coeff)
_=plt.xticks(range(len(clmns1)),clmns1,rotation=60)
_=plt.ylabel('Coefficients')
plt.show()

# %%
lasso_coeff
# Out:
# array([ 0.00000000e+00,  0.00000000e+00, -1.03739674e-04, -0.00000000e+00,
#        -0.00000000e+00,  0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#        -1.33764142e-04,  0.00000000e+00,  1.64851877e-05,  5.04941920e-05,
#        -0.00000000e+00,  1.52271323e-04,  0.00000000e+00, -4.39571388e-03])

# %%
lassp=lasso.predict(x_test[clmns1])

# %%
lassp
# Out:
# array([0.66402167, 0.32873593, 0.6429961 , ..., 0.93194544, 0.71725583,
#        0.33575389])

# %%
y_test
# Out:
# 1662101    0.4783
# 1104834    0.3846
# 2221450    0.9167
# 85169      0.0769
# 1018615    0.4074
# 3845461    0.0000
# 4299214    0.2692
# 3167712    0.1765
# 423023     0.6735
# 1203082    0.3261
# 464583     0.8969
# 495853     0.2128
# 2857774    0.2222
# 2340432    0.0000
# 3446457    0.3462
# 359987     1.0000
# 2855709    0.8936
# 2252982    0.7755
# 2976030    0.6452
# 672967     0.9655
# 1239258    0.6667
# 3994852    0.8061
# 3135627    0.9792
# 2093266    0.2340
# 492769     0.1277
# 2421987    0.7174
# 3455287    0.5870
# 3080802    0.9362
# 265953     0.8889
# 1414044    0.8846
#             ...
# 3074674    0.3571
# 2228566    0.1250
# 168306     0.6786
# 1351783    0.1111
# 2154029    0.0800
# 2805498    0.1154
# 3387166    0.2500
# 3335497    0.4444
# 1250847    0.8409
# 4203726    0.9259
# 1117983    0.8846
# 3880412    0.0741
# 4120140    0.1860
# 2686860    0.0400
# 3883874    0.1111
# 1203108    0.4074
# 3967318    0.5625
# 4309162    0.4468
# 2619583    0.1020
# ...

# %%
#mean square error
np.mean(lassp-y_test)**2
# Out:
# 2.8053553321144675e-08

# %%
from sklearn.linear_model import Ridge
ridge=Ridge(alpha=0.1)
ridge_coeff=ridge.fit(df[clmns1],df2['winPlacePerc']).coef_

# %%
ridge_coeff
# Out:
# array([ 1.35374157e-02,  1.80163907e-02,  7.67179124e-05, -1.76089411e-02,
#         1.53048696e-03, -7.54378055e-05, -9.21115634e-03, -1.38169894e-01,
#        -1.58279342e-05,  9.57323013e-03,  7.08933001e-06,  1.41451206e-04,
#        -6.02462544e-03,  1.07895209e-04,  1.00165910e-02, -7.37660599e-03])

# %%
rp=ridge.predict(x_test[clmns1])

# %%
np.mean(rp-y_test)**2
# Out:
# 1.513094003836046e-08

# %%
y=y_test.dropna()
#y1=y.reshape(-1,1)
type(y)

# %%
x_test.fillna(x_test.mean())

# %%
from sklearn.metrics import r2_score
print("Training scores")
print("Accuracy for linear model=",reg.score(df[clmns1],df2['winPlacePerc']))
print("Accuracy for lasso model=",lasso.score(df[clmns1],df2['winPlacePerc']))
print("Accuracy for ridge model=",ridge.score(df[clmns1],df2['winPlacePerc']))
# Out:
# Training scores
# Accuracy for linear model= 0.8062933921584969
# Accuracy for lasso model= 0.7568583366174666
# Accuracy for ridge model= 0.8062933921584949

# %%
df23=np.where(df22[clmns1].values>=np.finfo(np.float64).max)

# %%
x1=df22.head(100000)

# %%
from sklearn.metrics import r2_score
print("Testing Score")
print("Accuracy for linear model=",reg.score(x1[clmns1],x1['winPlacePerc']))
print("Accuracy for lasso model=",lasso.score(x1[clmns1],x1['winPlacePerc']))
print("Accuracy for ridge model=",ridge.score(x1[clmns1],x1['winPlacePerc']))
# Out:
# Testing Score
# Accuracy for linear model= 0.8062491790976594
# Accuracy for lasso model= 0.7568655984203233
# Accuracy for ridge model= 0.8062491791465454

# %%
from sklearn.decomposition import PCA
clmns=[ 'assists', 'boosts', 'damageDealt','DBNOs','headshotKills','heals','kills','killStreaks','longestKill','revives','rideDistance','swimDistance','vehicleDestroys','walkDistance','weaponsAcquired','killPlace']
ch=df[clmns]
#len(clmns)
pca=PCA(n_components=5)
pca_2d=pca.fit_transform(ch)
pca_2d
# Out:
# array([[-2.91327717e+02,  6.83715975e+02, -1.58815155e+02,
#         -5.51045506e+00, -7.57971728e+00],
#        [-1.04752400e+03, -6.50005282e+02, -6.85191770e+01,
#          5.50878091e+00, -5.10449150e-01],
#        [-9.10938684e+02, -4.09639841e+02,  2.47521621e+01,
#         -1.07578644e+01, -7.87588545e-01],
#        ...,
#        [-6.67962260e+02,  1.75108324e+01,  2.87012270e+02,
#         -3.65105033e+01, -1.03071730e+00],
#        [ 7.55739924e+02,  2.52822475e+03,  1.34669574e+02,
#          1.32719146e+01, -1.48050383e+01],
#        [ 3.89879690e+03, -4.19130587e+02, -2.36281532e+02,
#         -2.38792147e+01, -1.26789335e+01]])

# %%
p_df=pd.DataFrame(data=pca_2d,columns=['pc1','pc2','pc3','pc4','pc5'])
p_df
# Out:
#                  pc1          pc2         pc3        pc4         pc5
# 0        -291.327717   683.715975 -158.815155  -5.510455   -7.579717
# 1       -1047.523995  -650.005282  -68.519177   5.508781   -0.510449
# 2        -910.938684  -409.639841   24.752162 -10.757864   -0.787589
# 3        7331.869261 -3190.624783  -47.836603 -26.049136   -7.786594
# 4       -1015.689851  -594.253312    9.913970  -5.961410   -0.090612
# 5        -548.223100   230.583176 -126.414543  -0.318359   -4.975155
# 6        -882.749249  -359.964122   16.248912  -1.424069   -0.925365
# 7       -1070.193636  -690.776448   57.603122  24.438186    1.058809
# 8        -877.245237  -349.845243  -57.636345  -0.419008   -1.749698
# 9        -878.347740  -351.664721  -87.119489   4.370772   -1.909310
# 10       -649.387603    51.661011  -13.207967  -5.254089   -3.301089
# 11        963.027082  -737.325177 -102.473898  -7.413968   -4.350940
# 12      -1073.197709  -695.315956  -64.242614   6.891558   -0.130706
# ...

# %%
reg1=linear_model.LinearRegression()
reg1.fit(p_df,df2['winPlacePerc'])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
lasso1=Lasso(alpha=0.1)
lasso1.fit(p_df,df2['winPlacePerc'])
# Out:
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False)

# %%
ridge1=Ridge(alpha=0.1)
ridge1.fit(p_df,df2['winPlacePerc'])
# Out:
# Ridge(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
print("Training scores")
print("Accuracy for linear model=",reg1.score(p_df,df2['winPlacePerc']))
print("Accuracy for lasso model=",lasso1.score(p_df,df2['winPlacePerc']))
print("Accuracy for ridge model=",ridge1.score(p_df,df2['winPlacePerc']))
# Out:
# Training scores
# Accuracy for linear model= 0.6851774449044999
# Accuracy for lasso model= 0.6849904972758893
# Accuracy for ridge model= 0.6851774449044997

# %%
clmns=[ 'assists', 'boosts', 'damageDealt','DBNOs','headshotKills','heals','kills','killStreaks','longestKill','revives','rideDistance','swimDistance','vehicleDestroys','walkDistance','weaponsAcquired','killPlace']
ch=df[clmns]
#len(clmns)
pca=PCA(n_components=6)
pca_6d=pca.fit_transform(ch)
p_df1=pd.DataFrame(data=pca_6d,columns=['pc1','pc2','pc3','pc4','pc5','pc6'])
p_df1
# Out:
#                  pc1          pc2         pc3        pc4         pc5  \
# 0        -291.327717   683.715975 -158.815155  -5.510455   -7.579717
# 1       -1047.523995  -650.005282  -68.519177   5.508781   -0.510449
# 2        -910.938684  -409.639841   24.752162 -10.757864   -0.787589
# 3        7331.869261 -3190.624783  -47.836603 -26.049136   -7.786594
# 4       -1015.689851  -594.253312    9.913970  -5.961410   -0.090612
# 5        -548.223100   230.583176 -126.414543  -0.318359   -4.975155
# 6        -882.749249  -359.964122   16.248912  -1.424069   -0.925365
# 7       -1070.193636  -690.776448   57.603122  24.438186    1.058809
# 8        -877.245237  -349.845243  -57.636345  -0.419008   -1.749698
# 9        -878.347740  -351.664721  -87.119489   4.370772   -1.909310
# 10       -649.387603    51.661011  -13.207967  -5.254089   -3.301089
# 11        963.027082  -737.325177 -102.473898  -7.413968   -4.350940
# 12      -1073.197709  -695.315956  -64.242614   6.891558   -0.130706
# ...

# %%
reg2=linear_model.LinearRegression()
reg2.fit(p_df1,df2['winPlacePerc'])
lasso2=Lasso(alpha=0.1)
lasso2.fit(p_df1,df2['winPlacePerc'])
ridge2=Ridge(alpha=0.1)
ridge2.fit(p_df1,df2['winPlacePerc'])
print("Training scores")
print("Accuracy for linear model=",reg2.score(p_df1,df2['winPlacePerc']))
print("Accuracy for lasso model=",lasso2.score(p_df1,df2['winPlacePerc']))
print("Accuracy for ridge model=",ridge2.score(p_df1,df2['winPlacePerc']))
# Out:
# Training scores
# Accuracy for linear model= 0.7575435906929173
# Accuracy for lasso model= 0.7570053166886249
# Accuracy for ridge model= 0.7575435906929173

# %%
rp1=ridge2.predict(p_df1)
l2=np.mean(rp-df2['winPlacePerc'])**2
rp2=reg2.predict(p_df1)
l1=np.mean(rp-df2['winPlacePerc'])**2
rp3=lasso2.predict(p_df1)
l3=np.mean(rp3-df2['winPlacePerc'])**2


print("Mean squared error")
print("Regression model=",l1)
print("Lasso model=",l3)
print("Ridge model=",l2)
# Out:
# Mean squared error
# Regression model= 7.303754394041248e-36
# Lasso model= 1.718841167066546e-33
# Ridge model= 7.303754394041248e-36

# %%
from xgboost import XGBRegressor

# %%
model=XGBRegressor()
model.fit(p_df1,df2['winPlacePerc'])
# Out:
# C:\python_progs\anaconda\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# C:\python_progs\anaconda\lib\site-packages\xgboost\core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \
# [19:20:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bynode=1, colsample_bytree=1, gamma=0,
#        importance_type='gain', learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=None, subsample=1, verbosity=1)

# %%
model.score(p_df1,df2['winPlacePerc'])
# Out:
# 0.8339015008663815

# %%
model1=XGBRegressor()
model1.fit(df[clmns1],df2['winPlacePerc'])
# Out:
# C:\python_progs\anaconda\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# C:\python_progs\anaconda\lib\site-packages\xgboost\core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \
# [19:32:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bynode=1, colsample_bytree=1, gamma=0,
#        importance_type='gain', learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=None, subsample=1, verbosity=1)

# %%
model1.score(df[clmns1],df2['winPlacePerc'])#Testing score
# Out:
# 0.882798094124273

# %%
model1.score(x1[clmns1],x1['winPlacePerc'])#Test score
# Out:
# 0.8822977566529309

# %%
import skfuzzy as fuzz

# %%
cntr,u,u0,d,jm,p,fpc=fuzz.cluster.cmeans(df[clmns1],8,2,error=0.05,maxiter=1000,init=None)

# %%
fpc
# Out:
# 0.8384752032980651

# %%
cntr,u,u0,d,jm,p,fpc1=fuzz.cluster.cmeans(df[clmns1],9,2,error=0.05,maxiter=1000,init=None)

# %%
fpc1
# Out:
# 0.7664526703862276

# %%
cntr,u,u0,d,jm,p,fpc2=fuzz.cluster.cmeans(df[clmns1],7,2,error=0.05,maxiter=1000,init=None)

# %%
fpc2
# Out:
# 0.9945830509494109

# %%
cntr,u,u0,d,jm,p,fpc3=fuzz.cluster.cmeans(df[clmns1],6,2,error=0.05,maxiter=1000,init=None)

# %%
fpc3
# Out:
# 0.9638944202008413

# %%
cntr,u,u0,d,jm,p,fpc4=fuzz.cluster.cmeans(df[clmns1],10,2,error=0.05,maxiter=1000,init=None)

# %%
fpc4
# Out:
# 0.8204796025660476

# %%
cntr,u,u0,d,jm,p,fpc5=fuzz.cluster.cmeans(df[clmns1],5,2,error=0.05,maxiter=1000,init=None)

# %%
fpc5
# Out:
# 0.9233086485007682

# %%
import matplotlib.pyplot as plt
plt.plot([5,6,7,8,9,10],[10+fpc5,10+fpc3,10+fpc2,10+fpc,10+fpc1,10+fpc4],color='black',linewidth=2)
plt.show()
